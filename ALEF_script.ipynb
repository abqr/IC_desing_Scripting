# %%
import os
import numpy as np
import pandas as pd1
import shutil
import csv

# %%
os.system("vivado -mode batch -source add_project.tcl -tclargs {}".format("Vivado_codes"))
# Out:
# 0

# %%
os.system("vivado -mode batch -source synth_impl_run.tcl -tclargs {}".format("Vivado_codes"))
# Out:
# 256

# %%
import csv
for filename in os.listdir(input_directory):
        if filename.endswith('.txt'):

            DatapathDelay = []
            logic_delay=[]
            routing_delay=[]

            file_name=[]

            DynamicPower = []
            static_power=[]
            signal_power=[]
            logic_power=[]
            i_o_power=[]
            total_power=[]


            f7_muxes=[]
            lut_as_memory=[]
            lut_as_logic=[]
            slice_lut=[]
            lut1=[]
            lut2=[]
            lut3=[]
            lut4=[]
            lut5=[]
            lut6=[]
            lut7=[]


            with open("timing.txt") as f:
                lines = f.read()
                timing = lines.split("\n")
                    
                timing_info = [line for line in timing if "Data Path Delay" in line]
                dpd = float(timing_info[0].split()[3][:-2])
                DatapathDelay.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in DatapathDelay:
                        writer.writerow([val])

                timing_info = [line for line in timing if "Data Path Delay" in line]
                dpd = float(timing_info[0].split()[5][:-2])
                logic_delay.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in logic_delay:
                        writer.writerow([val])


                timing_info = [line for line in timing if "Data Path Delay" in line]
                dpd = float(timing_info[0].split()[8][:-2])
                routing_delay.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in routing_delay:
                        writer.writerow([val])

            with open("power.txt") as f:
                lines = f.read()
                timing = lines.split("\n")
                    
                timing_info = [line for line in timing if "Total On-Chip Power" in line]
                dpd = float(timing_info[0].split()[6])
                total_power.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in total_power:
                        writer.writerow([val])


                timing_info = [line for line in timing if "Static Power" in line]
                dpd = float(timing_info[0].split()[4])
                static_power.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in static_power:
                        writer.writerow([val])


                timing_info = [line for line in timing if "Signals" in line]
                dpd = float(timing_info[0].split()[3])
                signal_power.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in signal_power:
                        writer.writerow([val])


                timing_info = [line for line in timing if "Slice Logic" in line]
                dpd = float(timing_info[0].split()[4])
                logic_power.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in logic_power:
                        writer.writerow([val])


                timing_info = [line for line in timing if "Dynamic" in line]
                dpd = float(timing_info[0].split()[4])
                DynamicPower.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in DynamicPower:
                        writer.writerow([val])

                
            with open("utilization.txt") as f:
                lines = f.read()
                timing = lines.split("\n")
                    
                timing_info = [line for line in timing if "F7 Muxes" in line]
                dpd = float(timing_info[0].split()[3][:-2])
                f7_muxes.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in f7_muxes:
                        writer.writerow([val])

                timing_info = [line for line in timing if "LUT as Logic" in line]
                dpd = float(timing_info[0].split()[5][:-2])
                lut_as_logic.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in lut_as_logic:
                        writer.writerow([val])

                timing_info = [line for line in timing if "LUT as Memory" in line]
                dpd = float(timing_info[0].split()[8][:-2])
                lut_as_memory.append(dpd)
                print(dpd)
                with open('output.csv', 'w', newline='') as f:
                    writer = csv.writer(f)
                    for val in lut_as_memory:
                        writer.writerow([val])
